# %% [markdown]
# <a href="https://colab.research.google.com/github/OFCMatt/EBAC/blob/main/mod06_tarefa_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Módulo 6 tarefa 1
#
# #### 1) A base 'sinasc_RO_2019.csv' contém dados do sistema de nascidos vivos do DataSUS, cujo dicionário de dados está no arquivo 'Estrutura_SINASC_para_CD.pdf'. Carregue esses arquivos.

# %%
import pandas as pd

# Carregando a base de dados
df = pd.read_csv('SINASC_RO_2019.csv')

# Exibindo as 5 primeiras linhas
df.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...

# %% [markdown]
# ####  2) Monte um gráficos de barras com as variáveis APGAR1, APGAR5, SEXO, GESTACAO, ESTCIVMAE.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ajustando o estilo
sns.set(style='whitegrid')

# Lista das variáveis
variaveis = ['APGAR1', 'APGAR5', 'SEXO', 'GESTACAO', 'ESTCIVMAE']

# Criando gráficos
for var in variaveis:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=df, x=var, palette='viridis')
    plt.title(f'Frequência da variável {var}')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# <ipython-input-4-795226e5eee1>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=var, palette='viridis')
# <ipython-input-4-795226e5eee1>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=var, palette='viridis')
# <ipython-input-4-795226e5eee1>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=var, palette='viridis')
# <ipython-input-4-795226e5eee1>:13: FutureWarning:
#
# ...

# %% [markdown]
# #### 3) Monte um gráfico de barras mostrando o APGAR5 médio por CONSULTAS

# %%
plt.figure(figsize=(8, 4))
sns.barplot(data=df, x='CONSULTAS', y='APGAR5', palette='coolwarm', estimator='mean')
plt.title('APGAR5 médio por número de CONSULTAS')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-5-00640b1be50b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='CONSULTAS', y='APGAR5', palette='coolwarm', estimator='mean')

# %% [markdown]
# ####  4) Monte um painel com 4 gráficos mostrando as frequencias de SEXO, GESTACAO, ESTCIVMAE e CONSULTAS

# %%
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

variaveis = ['SEXO', 'GESTACAO', 'ESTCIVMAE', 'CONSULTAS']
cores = ['Blues', 'Greens', 'Oranges', 'Purples']

for ax, var, cor in zip(axs.flatten(), variaveis, cores):
    sns.countplot(data=df, x=var, ax=ax, palette=cor)
    ax.set_title(f'Frequência de {var}')
    ax.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-6-be461313e55b>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=var, ax=ax, palette=cor)
# <ipython-input-6-be461313e55b>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=var, ax=ax, palette=cor)
# <ipython-input-6-be461313e55b>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=var, ax=ax, palette=cor)
# <ipython-input-6-be461313e55b>:7: FutureWarning:
#
# ...
